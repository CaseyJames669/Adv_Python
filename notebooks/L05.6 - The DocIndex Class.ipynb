# %% [markdown]
# # Lesson 5.6 - The DocIndex class

# %% [markdown]
# This discussion will take you through the construction and testing of the **DocIndex class** in the cell below.
# Follow the steps to construct and test methods for DocIndex, in the order suggested.

# %% [markdown]
# ### Step 1: Understand the methods and behavior of the ADT
# > Below, on the left side of the table, we have an abstract description of the data and the operations on that data.
# On the right side of the table, there is a UML diagram of the intended class implementation of the ADT.
# The middle section of that diagram lists the intended data attributes needed to support the functionality of the class.

# %% [markdown]
# <center>
# <table border="0" cellpadding="2" cellspacing="10" width="90%">
# <tbody>
#     <td><b>ADT - DocIndex</b><p>
#         <b>Data description:</b>  Data type for representing and indexing a text document<br>
#         <b>Operations:</b>
# <ul>
#     <li> DocIndex(<b>contents</b>, <b>label</b>) - creates a new DocIndex instance initialized with a supplied document (<b>contents</b>) and its title (<b>label</b>)
#     <li> get_text() - returns a string representing the entire text of the document as submitted at create time
#     <li> get_label() - returns the name of the document
#     <li> get_words() - returns a list of alphabetically ordered words in the document
#     <li> get_context(term, lines) - return an iterator over occurences of the term in context
#         <li> str(<b>d</b>) - returns a string representation of the DocIndex object <b>d</b>
#             <li> repr(<b>d</b>) - returns a string representation of a synopsis of the DocIndex object <b>d</b>
#
# </ul>
#     </td>
# <td><div style="text-align: center;">
# <img src="files/figs/DocIndex.png" style="border: 0px solid ;
#                     width: 149px; height: 205px;"></a><p>
#     <b>UML Diagram For DocIndex</b>
# </tr>
# </tbody>
# </table>
# </center>

# %% [markdown]
# ### Step 2:  Construct the "template for your function
# > Most of this step has been done for you .. read carefully and identify the following:
# >> * We know we are going to use the word module, so import that now.  In general, you may determine that other modules must be imported as you are developing algorithms for the methods ... this is a "work in progress".
# * Write the class definition heading and the docstring class description for it.
# * From the description of desired behavior / operations in the table above, construct "stub" method definitions that include:
# >>> * method heading, complete with anticipated parameter list  ,
# >>> * docstring documentation with short description, preconditions, and postconditions,
# >>> * this is a "stub" .. i.e. a placeholder, for now, so its only statement is **pass** ... remember to remove this when  you supply code.
#
# >> * Supply unit test code.
# Test driven development helps ensure that your methods don't deviate from their agreed-upon/intended function.  Again, the methods and their unit tests are "works in progress" and subject to review/change (after agreement among the parties involved).
# Of course, sections of the unit test may need to be commented out until you have coded methods to address what the unit test code is testing.
#
# ### Step 3:  Write the code for the initializer (\_\_init\_\_).
# > This is where you initialize all of your instance data attributes.
# >> * **_lines** is a list of the lines in the document
# * **_label** is a string containing the document's name
# * **_index** is a dict {word:lines} indicating on which lines of the document the word apears
#
# > Note:  This is sufficient for maintaining the data and supporting all the class' methods.
# <p>
# At this point, you can't test much, but you can find errors in the syntax, etc by simply creating an instance of the class.
# **NOTE:**  In order to be able to **import word**, you must have a **word.py** or **word.pyc** (compiled with python 3.2) in your notebook folder.
#
# ### Step 4:  Write code to display the contents of a class instance.
# > Write the **\_\_str\_\_** and **\_\_repr\_\_** methods.
# These will give you a sense of whether or not your data is being correctly communicated and stored.
# Uncomment the unit test code lines that test these methods and inspect their output to verify that your object correctly represents/reports the data it is charged with maintaining.
#
# ### Step 5:  Continue implementing methods in an order that allows them to be tested after implementation.
# > In the current problem, you will probably want to save the implementation of **get_context** until last.  Though it doesn't depend on other methods, you will want to be certain that your representation of the data is correct before attacking this one.
# Don't make the mistake of coding all your methods and then testing.
# Often the effects of methods are interdependent and the more code you have to test, the more difficult it is to locate the source of an error.
# At times it may be necessary to even test a section of code for a method ... just as it is for any other function or script.  In those instances, you may find it beneficial to test code snippets in a Python shell (or a notebook cell).
#
# ### Step 6:  Code the 'get_context' method
# > Considerations in this method are:
# >> * **get_context** is a generator function and returns an iterator which produces **contexts**.
# * Each **context** is a **string** composed of (numbered) lines from the text.
# * When constructing the contexts for a given word, you need to use the line the word occurs on and surrounding lines ... you need to be sure those lines actually exist.  (Eg. if your word is on line 0, there will BE NO preceeding lines).
# Look at the python documentation for **enumerate**.
#
# ### Step 7:  Migrate your code to a module file
# > About this time, your testing is being constrained by the limits of the ipython notebook environment.
# You need to construct a file that you can execute from the command line so that you can use the unit test code that you created for your last assignment (which uses the python built-in **input** function.
# >> * Copy your code into a text editor, add your (required) file header and module documentation, and save it to your project folder.
# >> * Copy some text files to your project folder for testing your module.
# >> * Perform further testing / debugging / modifying.

# %%
import word

class DocIndex:
    ''' DocIndex(document, title) -> initialized object for one document
    
    Manage an index of words occurring in a text document, including
        document name and lines of the document.
    Can report
        document name
        list of unique words
        contexts for words 
    '''

    def __init__(self, contents, label):
        '''Construct a new index for the given document.

            Preconditons:
                contents - single string representing the complete document
                           contents
                label    - string which identifies the document name
            Postcondition: 
                instance contains an index of all the words in the document
        '''
        pass
        #_list (list) 
        #_label (str) THIS IS EASY
        #_index (dict{word:[line number]})
        
        # Initialize the instance variables from the parameter values
        # lines in document and document name, resp.
        

        # Obtain a dictionary of words and their locations in the document.
        
                        
    def get_text(self):
        '''Return the document text'''
        #join on a new line
        pass
   
        
    def get_label(self):
        '''Return the string which serves as the document name.'''

    def get_words(self):
        '''Return an ordered list of words appearing in this document.'''
        return sorted([wd for wd in self._index])
        
    
    def get_context(self, term, lines=1):
        '''Return an iterator over occurrences of the term in context.

        The generator will provide a stream of "contexts" for the specified
            (apparent) word in 'term'.
         A "context" displays the line containing the word, along with  
            the number of preceeding and succeeding lines specified in the 
            parameter 'lines' (if they exist) ... defaults to 1
            
        Preconditions:
            term is a string containing the word to look up
        
        Postcondition:
            a generator is created to deliver the stream of contexts
        '''
        term = word.word_strip(term)
        separator = 30 * '-'
        if term in self._index:
            for line_no in self._index[term]:
                out_list = [separator]
                #line_no - lines Must be <= 0 if -# than use 0 (max of 0 and line_no)
                #line_no
                #line_no + lines Doesn't matter if its the last line
                
                #'{:5d}  {}'.format(num,line)
                
                #yield
        else:
            #return nothing
    
    def __str__(self):
        '''Return a string with title, number of lines, number of unique words
        '''
        pass
        
    
    def __repr__(self):  
        '''Return a string with title and the contents of the document index
        '''
        pass
    
if __name__ == "__main__":
    test_data = '''Construct a multiline string ...
                that contains "punctuation", and possibly
                other extraneous characters, to test your 
                methods.  You should consider grabbing text
                from a document (programs aren't particularly
                suited for this purpose) and placing it in a
                docstring.'''
